# %%
#importing libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#reading our data set
df = pd.read_csv('../data/ufo_sightings_scrubbed.csv')

#checking first 10 outputs of dataframe
df.head(10)
# Out:
# C:\Users\foxyh\AppData\Local\Temp\ipykernel_7236\2521318126.py:2: DtypeWarning: Columns (5,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/ufo_sightings_scrubbed.csv')
#               datetime                  city state country     shape  \
# 0  1949-10-10 20:30:00            san marcos    tx      us  cylinder
# 1  1949-10-10 21:00:00          lackland afb    tx     NaN     light
# 2  1955-10-10 17:00:00  chester (uk/england)   NaN      gb    circle
# 3  1956-10-10 21:00:00                  edna    tx      us    circle
# 4  1960-10-10 20:00:00               kaneohe    hi      us     light
# 5  1961-10-10 19:00:00               bristol    tn      us    sphere
# 6  1965-10-10 21:00:00    penarth (uk/wales)   NaN      gb    circle
# 7  1965-10-10 23:45:00               norwalk    ct      us      disk
# 8  1966-10-10 20:00:00             pell city    al      us      disk
# ...

# %% [markdown]
# Looking at our data we can observe there is a mixed language describing the number of hours. However, we can see that seconds have been given in a more precise and singular style. We may want to drop the hours/minutes collumn and work solely with using the duration in terms of seconds. We should bin these to reduce clutter!
#
# We also may wish to split the dates and times columns so we can have access to data about when durring the day and what time of year sightings were most common. These insights could reflect if sightings are based off seasons. I would conjecture late spring to early fall in the northern states would have a higher sightings compared to colder times of the year when more people are indoors.
#
# Not sure what can be done with antidotal testimate. Dont need to immediately drop but probably cannot use until i figure a way to filter key words. Seeing one from the head, there is military personal involved.

# %%
#list of column names
df.columns
# Out:
# Index(['datetime', 'city', 'state', 'country', 'shape', 'duration (seconds)',
#        'duration (hours/min)', 'comments', 'date posted', 'latitude',
#        'longitude '],
#       dtype='object')

# %%
#checking data types and NaN
df.info()

#checking data types
#df.dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80332 entries, 0 to 80331
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   datetime              80332 non-null  object
#  1   city                  80332 non-null  object
#  2   state                 74535 non-null  object
#  3   country               70662 non-null  object
#  4   shape                 78400 non-null  object
#  5   duration (seconds)    80332 non-null  object
#  6   duration (hours/min)  80332 non-null  object
#  7   comments              80317 non-null  object
#  8   date posted           80332 non-null  object
#  9   latitude              80332 non-null  object
#  10  longitude             80332 non-null  float64
# dtypes: float64(1), object(10)
# memory usage: 6.7+ MB

# %% [markdown]
# it appears we have objects and not floats for certain values that should be quantitative

# %%
#checking for missing values (NaN)
df.isna().sum()
# Out:
# datetime                   0
# city                       0
# state                   5797
# country                 9670
# shape                   1932
# duration (seconds)         0
# duration (hours/min)       0
# comments                  15
# date posted                0
# latitude                   0
# longitude                  0
# dtype: int64

# %% [markdown]
# it would show that some are missing country, lets take a closer look and observe how many different countries we have in our data set and see if we can make a better decision based off the possible states, we also have access to latitude and longitude which we can use to get a much better approximation for a later reference of where these sightings have occured.

# %%
#lets see which countries are involved
df['country'].value_counts()

#let's look at the states
df['state'].value_counts()

#let's look at the shapes of uap's
df['shape'].value_counts()
# Out:
# shape
# light        16565
# triangle      7865
# circle        7608
# fireball      6208
# other         5649
# unknown       5584
# sphere        5387
# disk          5213
# oval          3733
# formation     2457
# cigar         2057
# changing      1962
# flash         1328
# rectangle     1297
# cylinder      1283
# diamond       1178
# chevron        952
# egg            759
# teardrop       750
# cone           316
# cross          233
# delta            7
# round            2
# crescent         2
# pyramid          1
# flare            1
# hexagon          1
# dome             1
# changed          1
# Name: count, dtype: int64

# %%
#find out the number of different shapes we have
len(df['shape'].unique())

#show unique shaped
df['shape'].unique()
# Out:
# array(['cylinder', 'light', 'circle', 'sphere', 'disk', 'fireball',
#        'unknown', 'oval', 'other', 'cigar', 'rectangle', 'chevron',
#        'triangle', 'formation', nan, 'delta', 'changing', 'egg',
#        'diamond', 'flash', 'teardrop', 'cone', 'cross', 'pyramid',
#        'round', 'crescent', 'flare', 'hexagon', 'dome', 'changed'],
#       dtype=object)

# %%
#lets check for duplications
df.duplicated(keep = False).sum()
# Out:
# 0

# %%
#for giggles, lets see a plot of sightings by year
#converting into a datetime column 
df['datetime'] = pd.to_datetime(df['datetime'])

#making a variable of year counts
year_counts = df.groupby(df['datetime'].dt.year).size()

# %%
#the plot
year_counts.plot(kind='bar', title= "Sightings by year")

#labels
plt.xlabel('Year')
plt.ylabel('Number of sightings')
# Out:
# Text(0, 0.5, 'Number of sightings')

# %% [markdown]
# We can see that there needs to be some binning done to get a better representation of which years and how much the number of sightings have occured. From our initial, rough graph we can at least observe some years exceeded over 7000 sightings while inital sightings were significantly lower, possibly single digits. This could be explained by several factors such as communication techniques, population density, and social or geopolitical events.
