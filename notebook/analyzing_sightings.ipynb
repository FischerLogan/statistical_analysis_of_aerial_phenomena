# %%
#importing libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#reading our data set
df = pd.read_csv('../data/ufo_sightings_scrubbed.csv')

#checking first 10 outputs of dataframe
df.head(10)
# Out:
# C:\Users\foxyh\AppData\Local\Temp\ipykernel_29648\2521318126.py:2: DtypeWarning: Columns (5,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/ufo_sightings_scrubbed.csv')
#               datetime                  city state country     shape  \
# 0  1949-10-10 20:30:00            san marcos    tx      us  cylinder
# 1  1949-10-10 21:00:00          lackland afb    tx     NaN     light
# 2  1955-10-10 17:00:00  chester (uk/england)   NaN      gb    circle
# 3  1956-10-10 21:00:00                  edna    tx      us    circle
# 4  1960-10-10 20:00:00               kaneohe    hi      us     light
# 5  1961-10-10 19:00:00               bristol    tn      us    sphere
# 6  1965-10-10 21:00:00    penarth (uk/wales)   NaN      gb    circle
# 7  1965-10-10 23:45:00               norwalk    ct      us      disk
# 8  1966-10-10 20:00:00             pell city    al      us      disk
# ...

# %%
#list of column names
df.columns
# Out:
# Index(['datetime', 'city', 'state', 'country', 'shape', 'duration (seconds)',
#        'duration (hours/min)', 'comments', 'date posted', 'latitude',
#        'longitude '],
#       dtype='object')

# %%
#checking data types and NaN
df.info()

#checking data types
df.dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80332 entries, 0 to 80331
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   datetime              80332 non-null  object
#  1   city                  80332 non-null  object
#  2   state                 74535 non-null  object
#  3   country               70662 non-null  object
#  4   shape                 78400 non-null  object
#  5   duration (seconds)    80332 non-null  object
#  6   duration (hours/min)  80332 non-null  object
#  7   comments              80317 non-null  object
#  8   date posted           80332 non-null  object
#  9   latitude              80332 non-null  object
#  10  longitude             80332 non-null  float64
# dtypes: float64(1), object(10)
# memory usage: 6.7+ MB
# datetime                 object
# city                     object
# state                    object
# country                  object
# ...

# %% [markdown]
# it appears we have objects and not floats for certain values that should be quantitative

# %%
#checking for missing values (NaN)
df.isna().sum()
# Out:
# datetime                   0
# city                       0
# state                   5797
# country                 9670
# shape                   1932
# duration (seconds)         0
# duration (hours/min)       0
# comments                  15
# date posted                0
# latitude                   0
# longitude                  0
# dtype: int64

# %% [markdown]
# it would show that some are missing country, lets take a closer look and observe how many different countries we have in our data set and see if we can make a better decision based off the possible states, we also have access to latitude and longitude which we can use to get a much better approximation for a later reference of where these sightings have occured.

# %%
#lets see which countries are involved
df['country'].value_counts()

#let's look at the states
df['state'].value_counts()

#let's look at the shapes of uap's
df['shape'].value_counts()
# Out:
# shape
# light        16565
# triangle      7865
# circle        7608
# fireball      6208
# other         5649
# unknown       5584
# sphere        5387
# disk          5213
# oval          3733
# formation     2457
# cigar         2057
# changing      1962
# flash         1328
# rectangle     1297
# cylinder      1283
# diamond       1178
# chevron        952
# egg            759
# teardrop       750
# cone           316
# cross          233
# delta            7
# round            2
# crescent         2
# pyramid          1
# flare            1
# hexagon          1
# dome             1
# changed          1
# Name: count, dtype: int64

# %%
#find out the number of different shapes we have
len(df['shape'].unique())

#show unique shaped
df['shape'].unique()
# Out:
# array(['cylinder', 'light', 'circle', 'sphere', 'disk', 'fireball',
#        'unknown', 'oval', 'other', 'cigar', 'rectangle', 'chevron',
#        'triangle', 'formation', nan, 'delta', 'changing', 'egg',
#        'diamond', 'flash', 'teardrop', 'cone', 'cross', 'pyramid',
#        'round', 'crescent', 'flare', 'hexagon', 'dome', 'changed'],
#       dtype=object)
